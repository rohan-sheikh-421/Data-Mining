# %% [markdown]
# Exercise 1

# %% [markdown]
# (a) Time in terms of AM or PM.

# %%
# binary, qualitative, and nominal.

# %% [markdown]
# (b) Brightness as measured by a light meter.

# %%
# continuous, quantitative, and ratio.

# %% [markdown]
# (c) Brightness as measured by people’s judgments.

# %%
# ordinal, qualitative, and subjective.

# %% [markdown]
# (d) Angles as measured in degrees between 00 and 3600

# %%
# continuou, quantitative and ratio.

# %% [markdown]
# (e) Bronze, Silver, and Gold medals as awarded at the Olympics.

# %%
# ordinal, qualitative and nominal.

# %% [markdown]
# (f) Height above sea level.

# %%
# continuous, quantitative, and ratio.

# %% [markdown]
# (g) Number of patients in a hospital.

# %%
# discrete, quantitative, and ratio.

# %% [markdown]
# (h) ISBN numbers for books. (Look up the format on the Web.)

# %%
# nominal, qualitative, and unique.

# %% [markdown]
# (i) Ability to pass light in terms of the following values: opaque, translucent, transparent.

# %%
# ordinal, qualitative, and nominal

# %% [markdown]
# (j) Military rank.

# %%
# ordinal, qualitative, and nominal

# %% [markdown]
# (k) Distance from the center of campus.

# %%
# continuous, quantitative, and ratio.

# %% [markdown]
# (l) Density of a substance in grams per cubic centimeter.

# %%
# continuous, quantitative, and ratio.

# %% [markdown]
# (m) Coat check number. (When you attend an event, you can often give your coat to someone who,
# in turn, gives you a number that you can use to claim your coat when you leave.)

# %%
# discrete, qualitative, and nominal.

# %% [markdown]
# Exercise 2

# %% [markdown]
# importing iris

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv("/content/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# 1. Classifying the dependent and Independent Variable

# %%
# independent variables (features)
independent_variables = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# dependent variable (target)
dependent_variable = 'Species'


X = df[independent_variables]
y = df[dependent_variable]

# %% [markdown]
# 2. Report how many examples we have of each feature (use df.shape() df.value_counts(), and
# df.dtypes)

# %%
# Print the shape of the DataFrame
print(df.shape)

# Print the value counts of each feature
print(df['SepalLengthCm'].value_counts())
print(df['SepalWidthCm'].value_counts())
print(df['PetalLengthCm'].value_counts())
print(df['PetalWidthCm'].value_counts())

# Print the data types of each feature
print(df.dtypes)
# Out:
# (150, 6)
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: SepalWidthCm, dtype: int64
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# 3. Report if any attribute has missing value

# %%
missing_values = df.isnull().sum()

# missing values in each column
print(missing_values)
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# 4. Report mean, median, mode, range, and STD for each attribute

# %%
# mode of each attribute
mode = df.mode(axis=0)
print(mode)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
descriptive_stats = df.describe()

# Print the descriptive statistics
print(descriptive_stats)
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# 5. Visualize data by creating pair plot, scattered plot, and histrograms, Heatmap Correlation

# %%
#  pair plot
sns.pairplot(df, hue='Species')

#  scatter plot
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df)

#  histogram for each feature
df.hist(figsize=(10, 8), bins=5)
# Out:
# <ipython-input-23-2388d8fc323d>:11: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >

# %%
#  heatmap of the correlation matrix
corr = df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <ipython-input-24-5e8acb32e660>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >
